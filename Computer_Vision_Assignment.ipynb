# %% [markdown]
# <a href="https://colab.research.google.com/github/gerryfrank10/ComputerVision/blob/main/Computer_Vision_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KNAPSACK PROBLEM USING COMPUTER VISION
#
# The aim of this notebook is to demonstrate the techniques and solution to a knapsack problem using computer vision techniques to detect the shapes of objects to be filled in the container or box.
# The use of computer vision techniques like contour detection, homography and deep learning approach (YOLO and R-CNN) to detect shapes along with their respective sizes

# %%
## Here we are going to demonstrate what to expect as final output of this notebook.

# %% [markdown]
# ## CV LIBRARY TO DETECT SHAPES

# %%
# Import necessary libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
print(cv2.__version__)
# Out:
# 4.11.0

# %%
# loading some sample images to use
im = cv2.imread('IMG_1600.jpeg')[:,:,::-1]
im = im.astype(np.uint8)
# cv2.rectangle(im, (100, 100), (200, 200), (0, 255, 0), 2)
plt.figure(figsize=(8,6))
plt.axis('off')
plt.imshow(im)

# %% [markdown]
# > How are we going to get the measurement of the image above `box` ?

# %%
print(hierarchy.shape)
# Out:
# (1, 27377, 4)

# %%
# Real box dimensions
reference_box_width =  2266


# detect contours
imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray, 127, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
largest_contour = max(contours, key=cv2.contourArea)
x, y, w, h = cv2.boundingRect(largest_contour)
print(f'The width is {w} and heigth is {h}')
cv2.rectangle(im, (x, y), (x + w, y + h), (0, 255, 0), 2)
plt.figure(figsize=(8,6))
plt.axis('off')
plt.imshow(im)
# contours = sorted(contours, key=cv2.contourArea, reverse=True)

# plt.imshow(imgray)

# cv2.drawContours(im, contours, -1, (0,255,0), 3)
# plt.figure(figsize=(8,6))
# plt.axis('off')
# plt.imshow(im)
# Out:
# The width is 2266 and heigth is 3236

# %%
# !apt install libgtk2.0-dev pkg-config
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgtk2.0-dev is already the newest version (2.24.33-2ubuntu2.1).
# The following packages were automatically installed and are no longer required:
#   libbz2-dev libpkgconf3 libreadline-dev
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   pkgconf r-base-dev
# The following NEW packages will be installed:
#   pkg-config
# 0 upgraded, 1 newly installed, 2 to remove and 34 not upgraded.
# Need to get 48.2 kB of archives.
# After this operation, 10.2 kB disk space will be freed.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 pkg-config amd64 0.29.2-1ubuntu3 [48.2 kB]
# Fetched 48.2 kB in 2s (27.5 kB/s)
# (Reading database ... 127832 files and directories currently installed.)
# Removing r-base-dev (4.5.0-2.2204.0) ...
# dpkg: pkgconf: dependency problems, but removing anyway as you requested:
# ...

# %%
roi_points = []

def select_roi(event, x, y, im, flags, param):
    global roi_points

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points = [(x, y)]
    elif event == cv2.EVENT_LBUTTONUP:
        roi_points.append((x, y))

        # Draw a rectangle around the ROI
        cv2.rectangle(im, roi_points[0], roi_points[1], (0, 255, 0), 2)
        cv2.imshow('Image', im)

        # Calculate and print dimensions (in pixels)
        width = abs(roi_points[1][0] - roi_points[0][0])
        height = abs(roi_points[1][1] - roi_points[0][1])
        print(f'Width: {width} pixels, Height: {height} pixels')
cv2.namedWindow('Image')
cv2.setMouseCallback('Image', im)
cv2.imshow('Image', im)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-52-d72ecde43544> in <cell line: 0>()
#      17         height = abs(roi_points[1][1] - roi_points[0][1])
#      18         print(f'Width: {width} pixels, Height: {height} pixels')
# ---> 19 cv2.namedWindow('Image')
#      20 cv2.setMouseCallback('Image', im)
#      21 cv2.imshow('Image', im)
#
# error: OpenCV(4.11.0) /io/opencv/modules/highgui/src/window.cpp:1284: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvNamedWindow'

# %% [markdown]
# ### GENERATING RANDOM IMAGES

# %%
# Generate Random shapes
def generate_random_images():
  pass

# %% [markdown]
# ### SHAPE DETECTION

# %%
# Contour detect
def contour_detect():
  pass

# Shape detect
def shape_detect():
  pass

# %% [markdown]
# ## DEEP LEARNING MODELS TO DETECT SHAPES

# %%
# Install packages
# !pip install ultralytics

# %%
# Using YOLO or R-CNN Pretrained models

# Loading the libraries
from ultralytics import YOLO

# Loading pretrained model using CV library
# Reference here https://opencv-tutorial.readthedocs.io/en/latest/yolo/yolo.html

# %%
# Detect shapes and contours,
# TODO

# %% [markdown]
# ## EVALUATION OF DETECTED SHAPES

# %% [markdown]
# ### CHECKING ACCURACY
#
# With the models shape detection we are going to calculate how good the model has detected the shapes with comparison to the real shape of the object we have specified.
# This approach will better enable us to choose the right model with correct parameters.

# %%
# Getting the performance

# %% [markdown]
# ## IMPROVED MODELS FOR OBJECT SHAPE DETECTION

# %%
# The improved model / Are we using pretrained ? or our own model

# %% [markdown]
# ## KNAPSACK FUNCTION / API
#
# KNAPSACK problems are ...

# %% [markdown]
# ### GENETIC ALGORITHM
# Genetic Algorithm solution for this scenarion ...

# %%
# genetic algorithm function we are going to load our approach to this problem

# %% [markdown]
# ### BRUTE FORCING

# %% [markdown]
# ### OTHER ALGORITHMS

# %% [markdown]
# ### PERFORMANCE EVALUATION

# %% [markdown]
# ## PLOTTING AND EVALUATING FINAL MODELS
